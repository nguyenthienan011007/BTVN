# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyenthienan011007/BTVN/blob/main/BaiTapipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#23.1
import folium
UEH = [10.77335544435826, 106.67756048060969]
BV = [10.775326367872198, 106.68137994614148]
TTTM = [10.770815358110555, 106.66987863423174]
HV = [10.773610721650776, 106.677037708153581]
TTTM2 = [10.776246273168042, 106.68092064110766]
m=folium.Map(location=[10.77335544435826, 106.67756048060969],zoom_start=16)
folium.Marker(UEH, popup = " Đại học Kinh tế Tp HCM ").add_to(m)
folium.Marker(BV, popup ="Bệnh viện Bình Dân - Khu điều trị Kỹ thuật cao").add_to(m)
folium.Marker(TTTM, popup ="Trung Tâm Thương Mại Vạn Hạnh").add_to(m)
folium.Marker(HV, popup ="Phân hiệu Học viện Hành chính và Quản trị công tại Thành phố Hồ Chí Minh").add_to(m)
folium.Marker(TTTM2, popup ="Vincom Plaza 3/2").add_to(m)


m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f7b480027bd0cbd5c7952db0302eaf2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f7b480027bd0cbd5c7952db0302eaf2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f7b480027bd0cbd5c7952db0302eaf2 = L.map(
#                 &quot;map_3f7b480027bd0cbd5c7952db0302eaf2&quot;,
#                 {
#                     center: [10.77335544435826, 106.67756048060969],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7deef33b310c604a67ee3ebd6ca93e93 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7deef33b310c604a67ee3ebd6ca93e93.addTo(map_3f7b480027bd0cbd5c7952db0302eaf2);
#
#
#             var marker_186fa20c3883a9bccd4fdc7273d8d78d = L.marker(
#                 [10.77335544435826, 106.67756048060969],
#                 {
# }
#             ).addTo(map_3f7b480027bd0cbd5c7952db0302eaf2);
#
#
#         var popup_f904f63391f5197b4041cb06ccb3a0a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ec551a66e8469fc53789fb3078eaa23 = $(`&lt;div id=&quot;html_8ec551a66e8469fc53789fb3078eaa23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt; Đại học Kinh tế Tp HCM &lt;/div&gt;`)[0];
#                 popup_f904f63391f5197b4041cb06ccb3a0a3.setContent(html_8ec551a66e8469fc53789fb3078eaa23);
#
#
#
#         marker_186fa20c3883a9bccd4fdc7273d8d78d.bindPopup(popup_f904f63391f5197b4041cb06ccb3a0a3)
#         ;
#
#
#
#
#             var marker_80d974092b17b8cf89345f6adbfe7a09 = L.marker(
#                 [10.775326367872198, 106.68137994614148],
#                 {
# }
#             ).addTo(map_3f7b480027bd0cbd5c7952db0302eaf2);
#
#
#         var popup_3f020260b4b5cb791714fe3f53b02726 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16225bf82f1953b13863492053fd38f5 = $(`&lt;div id=&quot;html_16225bf82f1953b13863492053fd38f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bệnh viện Bình Dân - Khu điều trị Kỹ thuật cao&lt;/div&gt;`)[0];
#                 popup_3f020260b4b5cb791714fe3f53b02726.setContent(html_16225bf82f1953b13863492053fd38f5);
#
#
#
#         marker_80d974092b17b8cf89345f6adbfe7a09.bindPopup(popup_3f020260b4b5cb791714fe3f53b02726)
#         ;
#
#
#
#
#             var marker_5321055297c8eda5ddf1df4c202ff0e9 = L.marker(
#                 [10.770815358110555, 106.66987863423174],
#                 {
# }
#             ).addTo(map_3f7b480027bd0cbd5c7952db0302eaf2);
#
#
#         var popup_42cf5818a3848d27f3b08c2de17059d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed04d2296f56957a5c9463c866f27a13 = $(`&lt;div id=&quot;html_ed04d2296f56957a5c9463c866f27a13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Trung Tâm Thương Mại Vạn Hạnh&lt;/div&gt;`)[0];
#                 popup_42cf5818a3848d27f3b08c2de17059d9.setContent(html_ed04d2296f56957a5c9463c866f27a13);
#
#
#
#         marker_5321055297c8eda5ddf1df4c202ff0e9.bindPopup(popup_42cf5818a3848d27f3b08c2de17059d9)
#         ;
#
#
#
#
#             var marker_f63345fb6bf4ce1abe09ba8bc7112faf = L.marker(
#                 [10.773610721650776, 106.67703770815358],
#                 {
# }
#             ).addTo(map_3f7b480027bd0cbd5c7952db0302eaf2);
#
#
#         var popup_2c4cb7cea392195bc1fb89e2c70d8562 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0dd1f900238a367d7a77f50214bd7bcc = $(`&lt;div id=&quot;html_0dd1f900238a367d7a77f50214bd7bcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Phân hiệu Học viện Hành chính và Quản trị công tại Thành phố Hồ Chí Minh&lt;/div&gt;`)[0];
#                 popup_2c4cb7cea392195bc1fb89e2c70d8562.setContent(html_0dd1f900238a367d7a77f50214bd7bcc);
#
#
#
#         marker_f63345fb6bf4ce1abe09ba8bc7112faf.bindPopup(popup_2c4cb7cea392195bc1fb89e2c70d8562)
#         ;
#
#
#
#
#             var marker_9e66606d79b7a93b27e4eaf55bf64bbe = L.marker(
#                 [10.776246273168042, 106.68092064110766],
#                 {
# }
#             ).addTo(map_3f7b480027bd0cbd5c7952db0302eaf2);
#
#
#         var popup_1627251daf742ecf5405996dcd4ab9d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ca2e2bfe3db3f8a9aadf226e0bfd662 = $(`&lt;div id=&quot;html_4ca2e2bfe3db3f8a9aadf226e0bfd662&quot; styl

# %%
#23.2
from geopy.distance import distance
import folium
from geopy.geocoders import Nominatim
from geopy.distance import geodesic
geolocator = Nominatim(user_agent="my app")
l1 = geolocator.geocode("UEH University, Ho Chi Minh City")
l2 = geolocator.geocode("Bệnh viện Nhi đồng 1")
l3 = geolocator.geocode("Trường Đại học Bách khoa - Đại học Quốc gia TP.HCM")
l4 = geolocator.geocode("Trung Tâm Thương Mại Vạn Hạnh")
l5 = geolocator.geocode("Bệnh viện Nhân Dân 115")
l6 = geolocator.geocode("Bệnh viện Da Liễu TP.HCM")
l7 = geolocator.geocode("Hội trường Thành uỷ")
l8 = geolocator.geocode("Hotel Nikko Saigon")
l9 = geolocator.geocode("Chợ hoa Hồ Thị Kỷ")
l10 = geolocator.geocode("Bệnh viện Chợ Rẫy")
print(f"Ten:{l1.address}")
print(f"Toa do:{l1.latitude}, {l1.longitude}")
print(f"Ten:{l2.address}")
print(f"Toa do:{l2.latitude}, {l2.longitude}")
print(f"Ten:{l3.address}")
print(f"Toa do:{l3.latitude}, {l3.longitude}")
print(f"Ten:{l4.address}")
print(f"Toa do:{l4.latitude}, {l4.longitude}")
print(f"Ten:{l5.address}")
print(f"Toa do:{l5.latitude}, {l5.longitude}")
print(f"Ten:{l6.address}")
print(f"Toa do:{l6.latitude}, {l6.longitude}")
print(f"Ten:{l7.address}")
print(f"Toa do:{l7.latitude}, {l7.longitude}")
print(f"Ten:{l8.address}")
print(f"Toa do:{l8.latitude}, {l8.longitude}")
print(f"Ten:{l9.address}")
print(f"Toa do:{l9.latitude}, {l9.longitude}")
print(f"Ten:{l10.address}")
print(f"Toa do:{l10.latitude}, {l10.longitude}")
l11 = (l1.latitude,l1.longitude)
d1= distance(Trungtam, l11).km
l12 = (l2.latitude,l2.longitude)
d2= distance(Trungtam, l12).km
l13 = (l3.latitude,l3.longitude)
d3= distance(Trungtam, l13).km
l14 = (l4.latitude,l4.longitude)
d4 = distance(Trungtam, l14).km
l15 = (l5.latitude,l5.longitude)
d5= distance(Trungtam, l15).km
l16 = (l6.latitude,l6.longitude)
d6= distance(Trungtam, l16).km
l17 = (l7.latitude,l7.longitude)
d7= distance(Trungtam, l17).km
l18 = (l8.latitude,l8.longitude)
d8= distance(Trungtam, l18).km
l19 = (l9.latitude,l9.longitude)
d9= distance(Trungtam, l19).km
l110 = (l10.latitude,l10.longitude)
d10= distance(Trungtam, l110).km


Trungtam=[10.773245903507496, 106.6779155566641]
m=folium.Map(location=Trungtam, zoom_start=16)
folium.Marker(Trungtam, popup="UEH cơ sở C",icon=folium.Icon(color='red', icon='star')).add_to(m)
folium.Marker(l11,popup=f"{l1} và cách {d1:.2f} km").add_to(m)
folium.Marker(l12,popup=f"{l2} và cách {d2:.2f} km").add_to(m)
folium.Marker(l13,popup=f"{l3} và cách {d3:.2f} km").add_to(m)
folium.Marker(l14,popup=f"{l4} và cách {d4:.2f} km").add_to(m)
folium.Marker(l15,popup=f"{l5} và cách {d5:.2f} km").add_to(m)
folium.Marker(l16,popup=f"{l6} và cách {d6:.2f} km").add_to(m)
folium.Marker(l17,popup=f"{l7} và cách {d7:.2f} km").add_to(m)
folium.Marker(l18,popup=f"{l8} và cách {d8:.2f} km").add_to(m)
folium.Marker(l19,popup=f"{l9} và cách {d9:.2f} km").add_to(m)
folium.Marker(l110,popup=f"{l10} và cách {d10:.2f} km").add_to(m)

folium.PolyLine(locations=[Trungtam,l11],color="red",weight=3).add_to(m)
folium.PolyLine(locations=[Trungtam,l12],color="red",weight=3).add_to(m)
folium.PolyLine(locations=[Trungtam,l13],color="red",weight=3).add_to(m)
folium.PolyLine(locations=[Trungtam,l14],color="red",weight=3).add_to(m)
folium.PolyLine(locations=[Trungtam,l15],color="red",weight=3).add_to(m)
folium.PolyLine(locations=[Trungtam,l16],color="red",weight=3).add_to(m)
folium.PolyLine(locations=[Trungtam,l17],color="red",weight=3).add_to(m)
folium.PolyLine(locations=[Trungtam,l18],color="red",weight=3).add_to(m)
folium.PolyLine(locations=[Trungtam,l19],color="red",weight=3).add_to(m)
folium.PolyLine(locations=[Trungtam,l110],color="red",weight=3).add_to(m)








m
# Out:
# Ten:Đại học Kinh tế Thành phố Hồ Chí Minh - Cơ sở A, Nguyễn Đình Chiểu, Khu phố 4, Phường Xuân Hòa, Thủ Đức, Thành phố Hồ Chí Minh, 71006, Việt Nam
# Toa do:10.7830141, 106.6948927
# Ten:Bệnh viện Nhi đồng 1, 532, Đường 3 Tháng 2, Khu phố 24, Phường Vườn Lài, Thủ Đức, Thành phố Hồ Chí Minh, 72712, Việt Nam
# Toa do:10.7688907, 106.6704163
# Ten:Trường Đại học Bách khoa (cơ sở 2), Đường Quảng Trường Sáng Tạo, Khu đô thị Đại học Quốc gia Thành phố Hồ Chí Minh, Phường Đông Hòa, Dĩ An, Thành phố Hồ Chí Minh, 00084, Việt Nam
# Toa do:10.8811139, 106.8060415
# Ten:Trung Tâm Thương Mại Vincom Plaza Gò Vấp, Phan Văn Trị, Gò Vấp, Phường Hạnh Thông, Thủ Đức, Thành phố Hồ Chí Minh, 71400, Việt Nam
# Toa do:10.8267295, 106.6892044
# Ten:Bệnh viện Nhân dân 115, 527, Sư Vạn Hạnh, Khu phố 15, Phường Hòa Hưng, Thủ Đức, Thành phố Hồ Chí Minh, 72117, Việt Nam
# Toa do:10.7744865, 106.6665778
# Ten:Bệnh viện Da liễu, Nguyễn Thông, Khu phố 1, Phường Xuân Hòa, Thủ Đức, Thành phố Hồ Chí Minh, 70001, Việt Nam
# Toa do:10.7767953, 106.6867655
# Ten:Hội trường Thành ủy, Lý Chính Thắng, Khu phố 11, Phường Nhiêu Lộc, Thủ Đức, Thành phố Hồ Chí Minh, 70001, Việt Nam
# Toa do:10.7801153, 106.6825219
# Ten:Khách sạn Nikko Saigon, 235, Nguyễn Văn Cừ, Khu phố 5, Phường Cầu Ông Lãnh, Thủ Đức, Thành phố Hồ Chí Minh, 72760, Việt Nam
# Toa do:10.764275, 106.6829603
# Ten:Chợ hoa Hồ Thị Kỷ, Hồ Thị Kỷ, Khu phố 37, Phường Vườn Lài, Thủ Đức, Thành phố Hồ Chí Minh, 72712, Việt Nam
# Toa do:10.7657675, 106.6772716
# Ten:Bệnh viện Chợ Rẫy, 201B, Đường Nguyễn Chí Thanh, Khu phố 12, Phường Chợ Lớn, Thủ Đức, Thành phố Hồ Chí Minh, 72415, Việt Nam
# Toa do:10.7566964, 106.6597263
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_87c986c36b17f6678971c51e960afb37 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_87c986c36b17f6678971c51e960afb37&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_87c986c36b17f6678971c51e960afb37 = L.map(
#                 &quot;map_87c986c36b17f6678971c51e960afb37&quot;,
#                 {
#                     center: [10.773245903507496, 106.6779155566641],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e97f8283155dc5e3c26c43df661fbc46 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e97f8283155dc5e3c26c43df661fbc46.addTo(map_87c986c36b17f6678971c51e960afb37);
#
#
#             var marker_feda107d6000eca08ec9b44bac0ca065 = L.marker(
#                 [10.773245903507496, 106.6779155566641],
#                 {
# }
#             ).addTo(map_87c986c36b17f6678971c51e960afb37);
#
#
#             var icon_a02a1acf6d1041e4d3e2566844785c43 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;star&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_0ecfdaa01b10fc129d33e2f51f7a8bcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d39b98ceb57d3c69a8944b0ae4d96a05 = $(`&lt;div id=&quot;html_d39b98ceb57d3c69a8944b0ae4d96a05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UEH cơ sở C&lt;/div&gt;`)[0];
#                 popup_0ecfdaa01b10fc129d33e2f51f7a8bcb.setContent(html_d39b98ceb57d3c69a8944b0ae4d96a05);
#
#
#
#         marker_feda107d6000eca08ec9b44bac0ca065.bindPopup(popup_0ecfdaa01b10fc129d33e2f51f7a8bcb)
#         ;
#
#
#
#
#                 marker_feda107d6000eca08ec9b44bac0ca065.setIcon(icon_a02a1acf6d1041e4d3e2566844785c43);
#
#
#             var marker_d617ff2c27da8e6471bdafafbeddf95e = L.marker(
#                 [10.7830141, 106.6948927],
#                 {
# }
#             ).addTo(map_87c986c36b17f6678971c51e960afb37);
#
#
#         var popup_26e8a0d38dadea4e35ee55a77dd6a275 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c25f04d6f963f1d698ab57b08c057993 = $(`&lt;div id=&quot;html_c25f04d6f963f1d698ab57b08c057993&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Đại học Kinh tế Thành phố Hồ Chí Minh - Cơ sở A, Nguyễn Đình Chiểu, Khu phố 4, Phường Xuân Hòa, Thủ Đức, Thành phố Hồ Chí Minh, 71006, Việt Nam và cách 2.15 km&lt;/div&gt;`)[0];
#                 popup_26e8a0d38dadea4e35ee55a77dd6a275.setContent(html_c25f04d6f963f1d698ab57b08c057993);
#
#
#
#         marker_d617ff2c27da8e6471bdafafbeddf95e.bindPopup(popup_26e8a0d38dadea4e35ee55a77dd6a275)
#         ;
#
#
#
#
#             var marker_722095f991e753ea2f5fb5f2bdaffc36 = L.marker(
#                 [10.7688907, 106.6704163],
#                 {
# }
#             ).addTo(map_87c986c36b17f6678971c51e960afb37);
#
#
#         var popup_434bc83789d78320608c1f830e186340 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9bcbbcfd5cf78f83646d91fe4d0c7a7 = $(`&lt;div id=&quot;html_d9bcbbcfd5cf78f83646d91fe4d0c7a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bệnh viện Nhi đồng 1, 532, Đường 3 Tháng 2, Khu phố 24, Phường Vườn Lài, Thủ Đức, Thành phố Hồ Chí Minh, 72712, Việt Nam và cách 0.95 km&lt;/div&gt;`)[0];
#                 popup_434bc83789d78320608c1f830e186340.setContent(html_d9bcbbcfd5cf78f83646d91fe4d0c7a7);
#
#
#
#         marker_722095f991e753ea2f5fb5f2bdaffc36.bindPopup(popup_434bc83789d78320608c1f830e186340)
#         ;
#
#
#
#
#             var marker_9d0ca0c67b91098e03254dfd28c5afb7 = L.marker(
#                 [10.8811139, 106.8060415],
#                 {
# }
#             ).addTo(map_87c986c36b17f6678971c51e960afb37);
#
#
#         var popup_b8dbedd3a11e490e5067d9d18e2760a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_497a87d4b9f0e4ecdb1509f5742b7cdb = $(`&lt;div id=&quot;html_497a87d4b9f0e4ecdb1509f5742b7cdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Trường Đại học Bách khoa (cơ sở 2), Đường Quảng Trường Sáng Tạo, Khu đô thị Đại học Quốc gia Thành phố Hồ Chí Minh, Phường Đông Hòa, Dĩ An, Thành phố Hồ Chí Minh, 00084, Việt Nam và cách 18.4

# %%
#23.3
from folium.plugins import HeatMap
import folium
delivery_points = [
    [10.773100426447256, 106.67757994143231], [10.774416223115807, 106.67905835420152], [10.774564698024948, 106.67571244065547],
    [10.772331965776596, 106.6748889344571], [10.770937054209497, 106.67726425094064], [10.772804780110153, 106.68208390216245], [10.772832862098628, 106.67489588224917],[10.775200709422563, 106.67547404717972] ]
m = folium.Map(location=[10.773100426447256, 106.67757994143231], zoom_start=18)
HeatMap(delivery_points).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ee430f3842bd85c1064b7dc817e3ece {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ee430f3842bd85c1064b7dc817e3ece&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ee430f3842bd85c1064b7dc817e3ece = L.map(
#                 &quot;map_7ee430f3842bd85c1064b7dc817e3ece&quot;,
#                 {
#                     center: [10.773100426447256, 106.67757994143231],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 18,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6513a51d91b4f12100faeeea2d6daed0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6513a51d91b4f12100faeeea2d6daed0.addTo(map_7ee430f3842bd85c1064b7dc817e3ece);
#
#
#             var heat_map_9d511e39c074b88b6b4c27e2ed7376af = L.heatLayer(
#                 [[10.773100426447256, 106.67757994143231], [10.774416223115807, 106.67905835420152], [10.774564698024948, 106.67571244065547], [10.772331965776596, 106.6748889344571], [10.770937054209497, 106.67726425094064], [10.772804780110153, 106.68208390216245], [10.772832862098628, 106.67489588224917], [10.775200709422563, 106.67547404717972]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 18,
#   &quot;radius&quot;: 25,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_9d511e39c074b88b6b4c27e2ed7376af.addTo(map_7ee430f3842bd85c1064b7dc817e3ece);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#23.5
import folium
khohang=[10.773271126486994, 106.67764631129579]
m = folium.Map(location=khohang, zoom_start=16)
folium.Marker(khohang, popup="Kho hàng", color="red", icon=folium.Icon(color="red")).add_to(m)
folium.Circle([10.774841542986838, 106.68013540121397],color="green",fill=True, radius= 200, popup="Khu vực giao hàng nhanh cách kho hàng 3km",fill_opacity=0.2).add_to(m)
folium.Circle([10.77811066373044, 106.67230100833257],color="yellow",fill=True, radius=250, popup="Khu vực giao hàng trung bình cách kho hàng 7 km",fill_opacity=0.2).add_to(m)
folium.Circle([10.764330109001872, 106.6671604688634],color="red",fill=True, radius= 350, popup="Khu vực giao hàng chậm cách kho hàng 9km",fill_opacity=0.2).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2dee7d6962670d0beba21b942164b21e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2dee7d6962670d0beba21b942164b21e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2dee7d6962670d0beba21b942164b21e = L.map(
#                 &quot;map_2dee7d6962670d0beba21b942164b21e&quot;,
#                 {
#                     center: [10.773271126486994, 106.67764631129579],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0432275a013f9ed6db4e8ee9cc4c94e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0432275a013f9ed6db4e8ee9cc4c94e1.addTo(map_2dee7d6962670d0beba21b942164b21e);
#
#
#             var marker_d6ebd68b7c2f675883792a7d045be461 = L.marker(
#                 [10.773271126486994, 106.67764631129579],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_2dee7d6962670d0beba21b942164b21e);
#
#
#             var icon_c7be95fe2aaad61f3bbc4b1de0f41283 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_3ae3cb1adfa25aa76c6e0790bd301323 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c54aaaf69b2209f08a475e89ea27477e = $(`&lt;div id=&quot;html_c54aaaf69b2209f08a475e89ea27477e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kho hàng&lt;/div&gt;`)[0];
#                 popup_3ae3cb1adfa25aa76c6e0790bd301323.setContent(html_c54aaaf69b2209f08a475e89ea27477e);
#
#
#
#         marker_d6ebd68b7c2f675883792a7d045be461.bindPopup(popup_3ae3cb1adfa25aa76c6e0790bd301323)
#         ;
#
#
#
#
#                 marker_d6ebd68b7c2f675883792a7d045be461.setIcon(icon_c7be95fe2aaad61f3bbc4b1de0f41283);
#
#
#             var circle_39e9d76965fbcf990e5a91ce6294025a = L.circle(
#                 [10.774841542986838, 106.68013540121397],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2dee7d6962670d0beba21b942164b21e);
#
#
#         var popup_2512959829e2eed8b69dff881cfffba9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f3e62a649924836d7a9d5404b17d718 = $(`&lt;div id=&quot;html_3f3e62a649924836d7a9d5404b17d718&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Khu vực giao hàng nhanh cách kho hàng 3km&lt;/div&gt;`)[0];
#                 popup_2512959829e2eed8b69dff881cfffba9.setContent(html_3f3e62a649924836d7a9d5404b17d718);
#
#
#
#         circle_39e9d76965fbcf990e5a91ce6294025a.bindPopup(popup_2512959829e2eed8b69dff881cfffba9)
#         ;
#
#
#
#
#             var circle_1bddecc7c770ce19f0d007432ec7202c = L.circle(
#                 [10.77811066373044, 106.67230100833257],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 250, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2dee7d6962670d0beba21b942164b21e);
#
#
#         var popup_85adc588fcb1aad4a1e8afc61bdc3acf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68e2f1b698c64faa9590ff81e5b0dd32 = $(`&lt;div id=&quot;html_68e2f1b698c64faa9590ff81e5b0dd32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Khu vực giao hàng trung bình cách kho hàng 7 km&lt;/div&gt;`)[0];
#                 popup_85adc588fcb1aad4a1e8afc61bdc3acf.setContent(html_68e2f1b698c64faa9590ff81e5b0dd32);
#
#
#
#         circle_1bddecc7c770ce19f0d007432ec7202c.bindPopup(p

# %%
import folium
nhakho={
    "Kho thứ nhất": [10.772993904229107, 106.67724557469425],
    "Kho thứ hai": [10.774827814292141, 106.6802281910496],
    "Kho thứ ba": [10.77520724256515, 106.6766662175761]
}
m=folium.Map(location=[10.773457652658673, 106.6774601514226],zoom_start=16)
for name,loc in nhakho.items():
  folium.Marker(loc,popup=name, icon=folium.Icon(color="blue")).add_to(m)
  folium.Circle(loc,radius=200,color="red", fill=True, fill_opacity=0.2).add_to(m)
donhang=[{"diachi": [10.766735284815384, 106.68045341881145], "status":"Thời gian giao nhanh"},
{"diachi": [ 10.76638540479643, 106.66148090345771], "status": "Thời gian giao trung bình"},
{"diachi": [10.753036426494953, 106.66878571449656], "status":"Thời gian giao chậm"}]
for order in donhang:
  color = {"Thời gian giao nhanh":"green", "Thời gian giao trung bình":"gray", "Thời gian giao chậm":"red"}[order["status"]]
  folium.Marker(order["diachi"],popup=order["status"],icon=folium.Icon(color=color)).add_to(m)



m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a52fb686ef018f71f6c2fe4d9d065c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a52fb686ef018f71f6c2fe4d9d065c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a52fb686ef018f71f6c2fe4d9d065c6 = L.map(
#                 &quot;map_0a52fb686ef018f71f6c2fe4d9d065c6&quot;,
#                 {
#                     center: [10.773457652658673, 106.6774601514226],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ddeea61440806416ee0a505163fe96f8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ddeea61440806416ee0a505163fe96f8.addTo(map_0a52fb686ef018f71f6c2fe4d9d065c6);
#
#
#             var marker_baf38e8d4ecd3517fb4d60b2d9238fc4 = L.marker(
#                 [10.772993904229107, 106.67724557469425],
#                 {
# }
#             ).addTo(map_0a52fb686ef018f71f6c2fe4d9d065c6);
#
#
#             var icon_f9c7fe02af1da4443c6c9ca73b451785 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_1ebfb739a53a4002ab53181a265aff0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7903815b51b255dd7258c6785e12370a = $(`&lt;div id=&quot;html_7903815b51b255dd7258c6785e12370a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kho thứ nhất&lt;/div&gt;`)[0];
#                 popup_1ebfb739a53a4002ab53181a265aff0d.setContent(html_7903815b51b255dd7258c6785e12370a);
#
#
#
#         marker_baf38e8d4ecd3517fb4d60b2d9238fc4.bindPopup(popup_1ebfb739a53a4002ab53181a265aff0d)
#         ;
#
#
#
#
#                 marker_baf38e8d4ecd3517fb4d60b2d9238fc4.setIcon(icon_f9c7fe02af1da4443c6c9ca73b451785);
#
#
#             var circle_12300c94f0747dc99fbc2b282a838663 = L.circle(
#                 [10.772993904229107, 106.67724557469425],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0a52fb686ef018f71f6c2fe4d9d065c6);
#
#
#             var marker_b1d293d60dbd9962246228edd41a31f7 = L.marker(
#                 [10.774827814292141, 106.6802281910496],
#                 {
# }
#             ).addTo(map_0a52fb686ef018f71f6c2fe4d9d065c6);
#
#
#             var icon_5c839b0bbee745870890facd6536ce5c = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_267c6910fec4928d4f2d27a3b7d43fea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aba50d827e2edf68d6784926319f97c9 = $(`&lt;div id=&quot;html_aba50d827e2edf68d6784926319f97c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kho thứ hai&lt;/div&gt;`)[0];
#                 popup_267c6910fec4928d4f2d27a3b7d43fea.setContent(html_aba50d827e2edf68d6784926319f97c9);
#
#
#
#         marker_b1d293d60dbd9962246228edd41a31f7.bindPopup(popup_267c6910fec4928d4f2d27a3b7d43fea)
#         ;
#
#
#
#
#                 marker_b1d293d60dbd9962246228edd41a31f7.setIcon(icon_5c839b0bbee745870890facd6536ce5c);
#
#
#             var circle_7d98af4babeb9bdfa3cddc0707d6bc52 = L.circle(
#                 [10.774827814292141, 106.6802281910496],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 200, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
